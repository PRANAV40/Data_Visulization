# %% [markdown]
# **Steps of Data Analysis Project** :-
# * Create a Problem Statement.
# * Identify the data you want to analyze.
# * Explore and Clean the data set
# * Analyze the data to get useful insights.
# * Present the data in terms of report or dashbords using visualization.

# %% [markdown]
# **Importing importent Library**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Loding the data set which you want to perform data analysis**

# %%
df = pd.read_csv('//content//hotel_bookings 2.csv')

# %% [markdown]
# **Exploratory Data Analysis and Data Cleaning using pandas library**

# %%
df.head()  #Its return top 5 rows of the data set
# df.head(10)  #If you use any number in the head() function Its return number of rows from the data set
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail() #Its return last 5 rows of the data set
# df.tail(10) #If you use any number in the tail() function Its return number of rows from the data set
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 14685  Resort Hotel            1        259               2015
# 14686  Resort Hotel            1        259               2015
# 14687  Resort Hotel            1        259               2015
# 14688  Resort Hotel            1        259               2015
# 14689  Resort Hotel            1        259               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14685          September                        38                         17
# 14686          September                        38                         17
# 14687          September                        38                         17
# 14688          September                        38                         17
# 14689          September                        38                         17
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
df.shape #Its show the number of rows and columns in the data set
# Out:
# (14690, 32)

# %%
df.columns #Its show how many of columns in the data set
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info() #Its show the data type of columns in the data set and this is also show how many NULL values in data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14690 entries, 0 to 14689
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           14690 non-null  object
#  1   is_canceled                     14690 non-null  int64
#  2   lead_time                       14690 non-null  int64
#  3   arrival_date_year               14690 non-null  int64
#  4   arrival_date_month              14690 non-null  object
#  5   arrival_date_week_number        14690 non-null  int64
#  6   arrival_date_day_of_month       14690 non-null  int64
#  7   stays_in_weekend_nights         14690 non-null  int64
#  8   stays_in_week_nights            14690 non-null  int64
#  9   adults                          14690 non-null  int64
#  10  children                        14690 non-null  int64
#  11  babies                          14690 non-null  int64
# ...

# %%
df['reservation_status_date '] = pd.to_datetime(df['reservation_status_date'],format="%d/%m/%Y") #Its change the data type of selected columns in the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14690 entries, 0 to 14689
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           14690 non-null  object
#  1   is_canceled                     14690 non-null  int64
#  2   lead_time                       14690 non-null  int64
#  3   arrival_date_year               14690 non-null  int64
#  4   arrival_date_month              14690 non-null  object
#  5   arrival_date_week_number        14690 non-null  int64
#  6   arrival_date_day_of_month       14690 non-null  int64
#  7   stays_in_weekend_nights         14690 non-null  int64
#  8   stays_in_week_nights            14690 non-null  int64
#  9   adults                          14690 non-null  int64
#  10  children                        14690 non-null  int64
#  11  babies                          14690 non-null  int64
# ...

# %%
df.describe(include= 'object')  #
# Out:
#                hotel arrival_date_month   meal country market_segment  \
# count          14690              14690  14690   14253          14690
# unique             1                 12      5      86              6
# top     Resort Hotel               July     BB     PRT      Online TA
# freq           14690               2087  10584    8220           7387
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                 14690              14690              14690
# unique                    4                  9                 11
# top                   TA/TO                  A                  A
# freq                  11212               8612               7183
#
#        deposit_type customer_type reservation_status reservation_status_date
# count         14690         14689              14689                   14689
# unique            4             4                  3                     866
# ...

# %%
for col in df.describe(include= 'object').columns:
  print(col)
  print(df[col].unique())
  print('-'*50)
# Out:
# hotel
# ['Resort Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR']
# --------------------------------------------------
# market_segment
# ...

# %%
df.isnull().sum() #Its check the missing values of rows and columns in the data set and return the cloumn name and total values is missing in the data set
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                             437
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df.drop(columns=set(['company', 'agent']).intersection(df.columns), axis=1, inplace=True)
 # If you want to remove any column from the data set then use drop function with column name
df.dropna(inplace=True) # If you want to remove any rows with missing values from the data set then use dropna function

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe() # We can use describe() function for the summery statistics of the numerical column
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  14252.000000  14252.000000       14252.000000
# mean       0.711900    120.064693        2016.025400
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     37.000000        2015.000000
# 50%        1.000000     96.000000        2016.000000
# 75%        1.000000    182.000000        2017.000000
# max        1.000000    737.000000        2017.000000
# std        0.452894    100.559952           0.749655
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              14252.000000               14252.000000
# mean                  28.510735                  15.865352
# min                    1.000000                   1.000000
# 25%                   18.000000                   8.000000
# 50%                   29.000000                  16.000000
# 75%                   38.000000                  24.000000
# max                   53.000000                  31.000000
# ...

# %%
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
df = df[df['adr']<5000]

# %% [markdown]
# **Data Analysis and Visualization on Data set**

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)

plt.figure(figsize = (5,4))
plt.title('Reservation statues count')
plt.bar(['Not canceled','Canceled'],df['is_canceled'].value_counts(),edgecolor ='k', width=0.6)
plt.show()
# Out:
# is_canceled
# 1    0.7119
# 0    0.2881
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,4))
ax1 = sns.countplot(x = 'hotel', hue ='is_canceled',data = df, palette='Blues')
legend_labels,_ = ax1. get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation statues in differnet hotels', size = 20)
plt.xlabel('Hotel')
plt.ylabel('Number of Reservation')
plt.legend(['Not canceled','Canceled'])
plt.show()

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 1    0.7119
# 0    0.2881
# Name: proportion, dtype: float64

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# Series([], Name: proportion, dtype: float64)

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize = (20,8))
plt.title('Average Daily Rate in City and Resorts Hotel', fontsize=30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label='Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label='City Hotel')
plt.legend(fontsize=20)
# plt.show()

# %%
# Convert 'reservation_status_date' column to datetime format with the correct format string
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y')
df['month'] = df['reservation_status_date'].dt.month
# Plot
plt.figure(figsize=(16,8))
ax1 = sns.countplot(x='month', hue='is_canceled', data=df, palette='bright')
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1))
plt.title('Reservation statues per month', size=20)
plt.xlabel('Month')
plt.ylabel('Number of Reservations')
plt.grid()
plt.legend(['Not canceled', 'Canceled'])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per Month', fontsize=30)
plt.grid()
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.show()

# %%
canceled_data = df[df['is_canceled'] == 1]
top_10_country = canceled_data['country'].value_counts()[:10]
plt.figure(figsize=(15,8))
plt.title('ADR per Month', fontsize=30)
plt.pie(top_10_country, autopct = '%.2f', labels = top_10_country.index)
plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        7314
# Groups           2909
# Offline TA/TO    1907
# Direct           1425
# Corporate         654
# Complementary      43
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.513191
# Groups           0.204112
# Offline TA/TO    0.133806
# Direct           0.099986
# Corporate        0.045888
# Complementary    0.003017
# Name: proportion, dtype: float64

# %%
canceled_data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.599054
# Groups           0.200079
# Offline TA/TO    0.088114
# Direct           0.079933
# Corporate        0.029667
# Complementary    0.003154
# Name: proportion, dtype: float64

# %%
canceled_df_adr = canceled_data.groupby('reservation_status_date')[['adr']].mean()
canceled_df_adr.reset_index(inplace=True)
canceled_df_adr.sort_values('reservation_status_date', inplace=True)

not_canceled_data = df[df['is_canceled'] == 0]
not_canceled_df_adr = not_canceled_data.groupby('reservation_status_date')[['adr']].mean()
not_canceled_df_adr.reset_index(inplace=True)
not_canceled_df_adr.sort_values('reservation_status_date', inplace=True)

plt.figure(figsize=(20,6))
plt.title('Average Daily Rate', fontsize=30)
plt.plot(not_canceled_df_adr['reservation_status_date'],not_canceled_df_adr['adr'], label = 'Not Canceled')
plt.plot(canceled_df_adr['reservation_status_date'], canceled_df_adr['adr'], label = 'Canceled')
plt.legend()

# %%
canceled_df_adr = canceled_df_adr[(canceled_df_adr['reservation_status_date']>'2016') & (canceled_df_adr['reservation_status_date']<'2017-09')]
not_canceled_df_adr = not_canceled_df_adr[(not_canceled_df_adr['reservation_status_date']>'2016') & (not_canceled_df_adr['reservation_status_date']<'2017-09')]

# %%
plt.figure(figsize=(20,6))
plt.title('Average Daily Rate', fontsize=30)
plt.plot(not_canceled_df_adr['reservation_status_date'],not_canceled_df_adr['adr'], label = 'Not Canceled')
plt.plot(canceled_df_adr['reservation_status_date'], canceled_df_adr['adr'], label = 'Canceled')
plt.legend(fontsize=20)
